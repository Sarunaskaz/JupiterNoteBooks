# %%
import pandas as pd
import numpy as np

# %%
brent = pd.read_csv('NewData/BrentOilPrices.csv')

# %%
brent
# Out:
#               Date  Price
# 0        20-May-87  18.63
# 1        21-May-87  18.45
# 2        22-May-87  18.55
# 3        25-May-87  18.60
# 4        26-May-87  18.63
# ...            ...    ...
# 8355  Apr 15, 2020  19.80
# 8356  Apr 16, 2020  18.69
# 8357  Apr 17, 2020  19.75
# 8358  Apr 20, 2020  17.36
# 8359  Apr 21, 2020   9.12
#
# [8360 rows x 2 columns]

# %%
brent.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8360 entries, 0 to 8359
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    8360 non-null   object
#  1   Price   8360 non-null   float64
# dtypes: float64(1), object(1)
# memory usage: 130.8+ KB

# %%
brent.head() # skliaustuose galima irasyti kiek eiluciu nori, kad butu isspausdinta
# Out:
#         Date  Price
# 0  20-May-87  18.63
# 1  21-May-87  18.45
# 2  22-May-87  18.55
# 3  25-May-87  18.60
# 4  26-May-87  18.63

# %%
brent.tail(1) # parodo paskutine eil, arba daugiau nuo galo
# Out:
#               Date  Price
# 8359  Apr 21, 2020   9.12

# %%
brent = pd.read_csv('NewData/BrentOilPrices.csv', parse_dates=['Date'])
# Out:
# C:\Users\sarun\AppData\Local\Temp\ipykernel_3292\1018462660.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   brent = pd.read_csv('NewData/BrentOilPrices.csv', parse_dates=['Date'])

# %%
brent.head()
# Out:
#         Date  Price
# 0 1987-05-20  18.63
# 1 1987-05-21  18.45
# 2 1987-05-22  18.55
# 3 1987-05-25  18.60
# 4 1987-05-26  18.63

# %%
brent.plot(x= 'Date')
# Out:
# <Axes: xlabel='Date'>

# %%
ru = pd.read_csv('NewData/RU.csv', parse_dates=['Date'])

# %%
ru.head(3)
# Out:
#         Date    Open    High     Low   Close
# 0 1995-10-23  4.5065  4.5065  4.5065  4.5065
# 1 1995-10-24  4.5060  4.5060  4.5060  4.5060
# 2 1995-10-25  4.5060  4.5060  4.5060  4.5060

# %%
ru.plot(x='Date', y=['Open', 'High'])
# Out:
# <Axes: xlabel='Date'>

# %%
dust14 = pd.read_csv('NewData/DUS2014.csv')
dust14.head(10)
# Out:
#    svoris  stazas  darbo_laiko_dalis evrk  im_dydzio_kodas im_dydis amzius  \
# 0   35.03       0               0.58   XL                0     1_49  20-29
# 1    2.39       0               0.54   XN                0     1_49  20-29
# 2   16.70       0               0.56   XQ                2   GT_250  40-49
# 3   28.24       0               0.58   XE                0     1_49  30-39
# 4   54.82       0               1.09   XI                0     1_49  40-49
# 5   32.63       0               0.58   XI                0     1_49  30-39
# 6   15.61       0               0.56   XQ                2   GT_250    60+
# 7   29.36       0               1.13   XM                0     1_49  20-29
# 8    4.65       0               0.50   XD                0     1_49  20-29
# 9   64.88       0               0.58   XH                0     1_49  40-49
#
#    atostogu_dienos sutarties_rusis  virsvalandziu_bdu  ...  nuosavybe bdu_val  \
# ...

# %%
bdu_spalio = dust14['bdu_spalio'].values
print(bdu_spalio)
print(bdu_spalio.mean())
print(np.median(bdu_spalio))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 bdu_spalio = dust14['bdu_spalio'].values
#       2 print(bdu_spalio)
#       3 print(bdu_spalio.mean())
#
# NameError: name 'dust14' is not defined

# %%
dust14_small = dust14[['lytis','amzius','bdu_spalio','issilavinimas','profesija']]
dust14_small.head()
# Out:
#   lytis amzius  bdu_spalio issilavinimas  profesija
# 0     M  20-29        6.00            G4        261
# 1     F  20-29        6.00            G2        334
# 2     F  40-49        6.00            G4        221
# 3     F  30-39        6.00            G4        332
# 4     M  40-49       11.33            G2        962

# %%
#Duomenu atranka

y =dust14_small[dust14_small['lytis'] == 'F']
y.head(14)
# Out:
#    lytis amzius  bdu_spalio issilavinimas  profesija
# 1      F  20-29        6.00            G2        334
# 2      F  40-49        6.00            G4        221
# 3      F  30-39        6.00            G4        332
# 7      F  20-29       13.33            G2        531
# 10     F  40-49       10.00            G3        334
# 12     F  30-39        6.00            G4        241
# 13     F  20-29        9.00            G3        332
# 14     F  50-59       17.00            G4        263
# 15     F  20-29       31.67            G2        962
# 16     F  30-39        6.00            G3        241
# 20     F  30-39        6.00            G3        241
# 22     F    60+        6.00            G3        241
# 24     F  40-49        6.00            G2        332
# 28     F  30-39        6.67            G3        264

# %%
yvid = y['bdu_spalio'].mean()
ymediana = y['bdu_spalio'].median()
print(yvid, ymediana)
# Out:
# 2097.379658410087 1751.0

# %%
# koks buvo vyrų ir moterų vidutinis atlyginimas 2014 metais?
# rezulataą išspausdinkite vienas šalia kito:
# pvz 
# Vyrų x, moterų y atlyginimai

x =dust14_small[dust14_small['lytis'] == 'M']
xvid = x['bdu_spalio'].mean()

print(f'Moteru vid atlyginimas:{yvid}''\n' f'Vyru vid atlyginimas:{xvid}')
# Out:
# Moteru vid atlyginimas:2097.379658410087
# Vyru vid atlyginimas:2633.693743912158

# %%
dust14 = pd.read_csv('NewData/DUS2014.csv')
dust14.head(10)
# Out:
#    svoris  stazas  darbo_laiko_dalis evrk  im_dydzio_kodas im_dydis amzius  \
# 0   35.03       0               0.58   XL                0     1_49  20-29
# 1    2.39       0               0.54   XN                0     1_49  20-29
# 2   16.70       0               0.56   XQ                2   GT_250  40-49
# 3   28.24       0               0.58   XE                0     1_49  30-39
# 4   54.82       0               1.09   XI                0     1_49  40-49
# 5   32.63       0               0.58   XI                0     1_49  30-39
# 6   15.61       0               0.56   XQ                2   GT_250    60+
# 7   29.36       0               1.13   XM                0     1_49  20-29
# 8    4.65       0               0.50   XD                0     1_49  20-29
# 9   64.88       0               0.58   XH                0     1_49  40-49
#
#    atostogu_dienos sutarties_rusis  virsvalandziu_bdu  ...  nuosavybe bdu_val  \
# ...

# %%
dust14_small = dust14[['lytis','amzius','bdu_spalio','issilavinimas','profesija']]
dust14_small.head()
# Out:
#   lytis amzius  bdu_spalio issilavinimas  profesija
# 0     M  20-29        6.00            G4        261
# 1     F  20-29        6.00            G2        334
# 2     F  40-49        6.00            G4        221
# 3     F  30-39        6.00            G4        332
# 4     M  40-49       11.33            G2        962

# %%
m14g3 = dust14_small[(dust14_small['lytis'] == 'M') & (dust14_small['issilavinimas'] == 'G3')]
# Out:
#    lytis amzius  bdu_spalio issilavinimas  profesija
# 11     M  20-29        9.67            G3        315
# 18     M    60+        6.00            G3        312
# 19     M  20-29        6.00            G3        333
# 21     M  20-29       28.67            G3        241
# 25     M  50-59        6.00            G3        261

# %%
# atrinkite tik vyrus
# pagal išsilavinimą 
#  G1, G2, G3, G4
# ir suraskite jų vidutinius atlyginimus
# spausdinkite taip:
#  G1 x
# G2 y
# G3 e
# G4 e


# and ir or operatoriai:
# and &
# or |

x = dust14_small[(dust14_small['lytis'] == 'M') & (dust14_small['issilavinimas'] == 'G1')]
print(x['bdu_spalio'].mean())
y = dust14_small[(dust14_small['lytis'] == 'M') & (dust14_small['issilavinimas'] == 'G2')]
print(y['bdu_spalio'].mean())
e = dust14_small[(dust14_small['lytis'] == 'M') & (dust14_small['issilavinimas'] == 'G3')]
print(y['bdu_spalio'].mean())
d = dust14_small[(dust14_small['lytis'] == 'M') & (dust14_small['issilavinimas'] == 'G4')]
print(d['bdu_spalio'].mean())
# Out:
# 1762.3009536541888
# 2129.485699084385
# 2129.485699084385
# 4158.559151846785
